# %% [markdown]
# # Python Advance Assignment
# ### Assignment - 21

# %% [markdown]
# [1] What is a probability distribution, exactly? If the values are meant to be random, how can you predict them at all?

# %% [markdown]
# A probability distribution is a function under probability theory and statistics - one that gives us how probable different outcomes are in an experiment. It describes events in terms of their probabilities; this is out of all possible outcomes. Let’s take the probability distribution of a fair coin toss. Here, heads take a value of X=0.5 and tails gets X=0.5 too.

# %% [markdown]
# [2] Is there a distinction between true random numbers and pseudo-random numbers, if there is
# one? Why are the latter considered “good enough”?

# %% [markdown]
# Yes, there is a difference, pseudo-random numbers are generated by a program, these numbers are considered as good as a true random number.

# %% [markdown]
# [3] What are the two main factors that influence the behaviour of a "normal" probability distribution?

# %% [markdown]
# It is `mean` and `variance`.

# %% [markdown]
# [4] Provide a real-life example of a normal distribution?

# %% [markdown]
# Height measurement is an example of normal distribution.

# %% [markdown]
# [5] In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?

# %% [markdown]
# Number of trials decreases variance.

# %% [markdown]
# [6] What kind of object can be shuffled by using random.shuffle?

# %% [markdown]
# We can shuflle `list`, `str`, and `tuple` using random.shuffle.

# %% [markdown]
# [7] Describe the math package's general categories of functions?

# %% [markdown]
# The Math package's general categories of functions are:
#
# * Trigonometric functions
# * Quadratic functions
# * Exponential functions
# * Hyperbolic functions
# * Periodic functions
# * Arithmetic functions
# * Logarithimic functions
# * Conversions to Integer

# %% [markdown]
# [8] What is the relationship between exponentiation and logarithms?

# %% [markdown]
# Exponentiation is inverse of Logarithms.

# %% [markdown]
# [9] What are the three logarithmic functions that Python supports?

# %% [markdown]
# * `log2(x)` - logarithmic value of x to base 2
# * `log10(x)` - logarithmic value of x to base 10
# * `log1p(a)` - This function is used to compute logarithm(1+a)
